# %%
import pandas as pd
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['tip'].max()
# Out:
# 10.0

# %%
df['tip'].min()
# Out:
# 1.0

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Set plot style
sns.set(style="whitegrid")

# Create the plot with regression line
plt.figure(figsize=(10, 6))
ax = sns.regplot(
    x='total_bill',
    y='tip',
    data=df,
    scatter_kws={'color': 'skyblue', 's': 60, 'edgecolor': 'w'},
    line_kws={'color': 'red', 'linewidth': 2}
)

# Annotate only points where total_bill > 40
for i in range(len(df)):
    x = df['total_bill'].iloc[i]
    y = df['tip'].iloc[i]
    if x > 40:
        ax.text(x, y + 0.3, f"({x:.1f}, {y:.1f})", fontsize=8, color='darkblue')

# Add labels and title
plt.title('Total Bill vs Tip (Labeling High Bills Only)', fontsize=14)
plt.xlabel('Total Bill ($)', fontsize=12)
plt.ylabel('Tip ($)', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.lmplot(x='total_bill', y='tip', data=df)
plt.show()

# %%
#selecting features columns
x = df[['total_bill']]

#selecting target variable

y = df['tip']

# %%
from sklearn.linear_model import LinearRegression

# %%
#load the model
model = LinearRegression()

# %%
# Fit th model
model.fit(x,y)
# Out:
# LinearRegression()

# %%
# Lets predict the tip for a total bill of 50
total_bill = np.array([[16.99]])
predicted_tip = model.predict(total_bill)
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
tips = predicted_tip.tolist()[0]
print(f"Predicted tip for a total bill of ${total_bill.tolist()[0][0]}: ${tips:.2f}")
# Out:
# Predicted tip for a total bill of $16.99: $2.70

# %%
sns.lmplot(x='total_bill', y='tip', data=df)
